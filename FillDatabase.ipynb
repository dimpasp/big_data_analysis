# %%
import pandas as pd
import sqlalchemy
import pymysql
import time
import numpy as np
import joblib
pass

# %%
engine = sqlalchemy.create_engine('mysql://dimpasp:aris1914@localhost:3306/testenergy')

# %% [markdown]
# # give dataset

# %%
pd.options.mode.chained_assignment = None  # default='warn'

new_predict=joblib.load("New_predict_energy.joblib")

#pathOfDataset='C:/Users/User/Desktop/project/Energy_Dataset_Test.csv'
pathOfDataset='C:/Users/User/Desktop/project/project_for_master/Project/datasetForPrediction.csv'

df=pd.read_csv(pathOfDataset)
df.head()
# Out:
#    Unnamed: 0  Year  Month  Day  Hour  generation biomass  \
# 0       33064  2018     10    9    15               367.0
# 1       33065  2018     10    9    16               365.0
# 2       33066  2018     10    9    17               367.0
# 3       33067  2018     10    9    18               369.0
# 4       33068  2018     10    9    19               368.0
#
#    generation fossil brown coal/lignite  generation fossil gas  \
# 0                                 760.0                 6501.0
# 1                                 760.0                 7364.0
# 2                                 760.0                 7607.0
# 3                                 760.0                 7912.0
# 4                                 760.0                 7659.0
#
#    generation fossil hard coal  generation fossil oil  \
# 0                       4894.0                  312.0
# 1                       4943.0                  310.0
# 2                       4945.0                  312.0
# ...

# %%
clist = ['Year','Month','Day','Hour','generation biomass','generation fossil brown coal/lignite','generation fossil gas','generation fossil hard coal','generation fossil oil','generation hydro pumped storage consumption',
         'generation hydro run-of-river and poundage','generation hydro water reservoir','generation nuclear',
         'generation other','generation other renewable','generation solar',
         'generation waste','generation wind onshore']
new= df[clist]
new
# Out:
#       Year  Month  Day  Hour  generation biomass  \
# 0     2018     10    9    15               367.0
# 1     2018     10    9    16               365.0
# 2     2018     10    9    17               367.0
# 3     2018     10    9    18               369.0
# 4     2018     10    9    19               368.0
# ...    ...    ...  ...   ...                 ...
# 1995  2018     12   31    18               297.0
# 1996  2018     12   31    19               296.0
# 1997  2018     12   31    20               292.0
# 1998  2018     12   31    21               293.0
# 1999  2018     12   31    22               290.0
#
#       generation fossil brown coal/lignite  generation fossil gas  \
# 0                                    760.0                 6501.0
# 1                                    760.0                 7364.0
# 2                                    760.0                 7607.0
# 3                                    760.0                 7912.0
# ...

# %% [markdown]
# # εαν θελω ολο το dataset να αποθηκευεται

# %%
for ind in new.index:
    new.iloc[[ind]].to_sql('predictive_energy',engine, if_exists='append')
